# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
url = "https://www.alibaba.com/trade/search?spm=a2700.7724857.the-new-header_fy23_pc_search_bar.searchButton&tab=all&SearchText=laptop+cor+i7"

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/127.0.0.0 Safari/537.36',
    'Accept-Language': 'en-US,en;q=0.9'
}

# %%
webpage= requests.get(url)

# %%
webpage.content
# Out:
# b'        <!-- tangram:7027 begin-->\n\n\n<!DOCTYPE html>\n<html class="rwd" >\n<head>\n    <meta name="aplus-auto-exp-duration" content="300" />\n    <meta name="aplus-auto-exp-watchdom" content="throttle" />\n    <script>\n        window.__icbusearch_timing={};window.__icbusearch_timing.html_start = Date.now();\n                window.__aplus__sse__test = true;\n        window.__icbusearch_param_searchtext = "laptops core i7";\n        window.__icbusearch_mlp_locale = window.__icbusearch_mlp || "en_US".toLowerCase();\n        window.__icbusearch_mlp_locale_Underscore = "en_US";\n        window.__icbusearch_mlp__disable_rfq_iframe = false;\n    </script>\n    <meta content="text/html; charset=utf-8" http-equiv="Content-Type" />\n        \t<title>Laptops Core I7-Laptops Core I7 Manufacturers, Suppliers and Exporters on Alibaba.comPersonal &amp; Home laptops</title>\n    \t<meta name="keywords" content="Laptops Core I7 Manufacturers, Laptops Core I7 Suppliers, Laptops Core I7, Manufac
# ...

# %%
soup = BeautifulSoup(webpage.content, 'html.parser')

# %%
soup
# Out:
#  <!-- tangram:7027 begin-->
# <!DOCTYPE html>
#
# <html class="rwd">
# <head>
# <meta content="300" name="aplus-auto-exp-duration"/>
# <meta content="throttle" name="aplus-auto-exp-watchdom"/>
# <script>
#         window.__icbusearch_timing={};window.__icbusearch_timing.html_start = Date.now();
#                 window.__aplus__sse__test = true;
#         window.__icbusearch_param_searchtext = "laptops core i7";
#         window.__icbusearch_mlp_locale = window.__icbusearch_mlp || "en_US".toLowerCase();
#         window.__icbusearch_mlp_locale_Underscore = "en_US";
#         window.__icbusearch_mlp__disable_rfq_iframe = false;
#     </script>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>Laptops Core I7-Laptops Core I7 Manufacturers, Suppliers and Exporters on Alibaba.comPersonal &amp; Home laptops</title>
# ...

# %%
links = soup.find_all("a", attrs={'class': 'search-card-e-detail-wrapper'})

# %%
links[0]
# Out:
# <a class="search-card-e-detail-wrapper" href="//www.alibaba.com/product-detail/2024-New-Arrivals-4GB-8GB-Ram_1601206158706.html?s=p" target="_blank"><div class="search-card-m-product-features-gallery"><div class="search-card-m-product-features__icon" data-aplus-auto-card-mod="area=productIcon&amp;areaContent=ROHS&amp;target=detail"><div class="search-card-e-icon__certification-wrapper"><img alt="ROHS" class="search-card-e-icon__certification" loading="lazy" src="//s.alicdn.com/@sc04/kf/H5d22c75d0ad649539f72d3153d1c1e67B.jpeg_100x100.jpeg" style="height:16px"/></div></div></div></a>

# %%
links[0].get('href')
# Out:
# '//www.alibaba.com/product-detail/2024-New-Arrivals-4GB-8GB-Ram_1601206158706.html?s=p'

# %%
link = links[0].get('href')

# %%
Product_list = "https:" + link

# %%
print(Product_list)
# Out:
# https://www.alibaba.com/product-detail/2024-New-Arrivals-4GB-8GB-Ram_1601206158706.html?s=p

# %%
new_webpage = requests.get(Product_list)

# %%
new_webpage
# Out:
# <Response [200]>

# %%
new_soup = BeautifulSoup(new_webpage.content, 'html.parser')

# %%
#new_soup

# %%
s = new_soup.find("div", class_="product-title-container")

# %%
s.find_all('h1')
# Out:
# [<h1 title="2024 New Arrivals 4GB 8GB Ram 128GB 256GB 500GB 512GB 1TB HDD/ SSD Laptop Computer Order Transaction Listing For Cheapest i5">2024 New Arrivals 4GB 8GB Ram 128GB 256GB 500GB 512GB 1TB HDD/ SSD Laptop Computer Order Transaction Listing For Cheapest i5</h1>]

# %%
div_element = soup.find('div')

# %%
h2_element = div_element.find('h2', class_='search-card-e-title')

# %%
span_element = h2_element.find('span')

# %%
span_text = span_element.get_text(separator=' ', strip=True)
print(span_text)
# Out:
# Laptop Computer I7 -1065G7 15.6Inch Win10 Notebook Computer 128GB 256GB 512GB 1024GB OEM Gaming 8GB 16GB RAM Laptop I5 I3 I9

# %%
span_element = soup.find('span', {'data-spm-anchor-id': 'a2700.galleryofferlist.d_title.i0.422a5c0bBHnAj1'})

# %%
span_text = span_element.get_text(separator=' ', strip=True)
sprint(span_text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 span_text = span_element.get_text(separator=' ', strip=True)
#       2 sprint(span_text)
#
# AttributeError: 'NoneType' object has no attribute 'get_text'

# %%
link_1.find_all('h3')

# %%
price_divs=soup.div.find_all('div',class_="search-card-e-price-main")

# %%
for price_div in price_divs:
    price_text = price_div.get_text(strip=True)
    print(price_text)

# %%
new_soup.find("span", attrs={"id": "a2700.details.0.i38.61b33cd1Eb7mJr"})

# %%
price_divs=soup.div.find_all('h2',class_="search-card-e-title")

# %%
for price_div in price_divs:
    price_text = price_div.get_text(strip=True)
    print(price_text)

# %%
h2_elements = soup.find_all('h2', class_='search-card-e-title')

# Iterate over each h2 element and find the nested span
for h2 in h2_elements:
    span = h2.find('span')
    if span:
        # Get the text inside the span, including nested b tags
        print(span.get_text(separator=' ', strip=True))
